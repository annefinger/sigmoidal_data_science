# %% [markdown]
# <a href="https://colab.research.google.com/github/annefinger/sigmoidal_data_science/blob/main/gr%C3%A1fico_linhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráfico de Linhas
#
# O gráfico de linha é um tipo de gráfico que mostra a informação em forma de um conjunto de pontos (*markers*) conectados por segmentos de linha reta. É um dos tipos básicos de gráficos mais usados na maioria dos problemas
#
# <center><img src="https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_03/grafico_linha.png"width="400px"></center>
#
# Gráficos de linhas são ideais para mostrar alterações e tendências de dados em intervalos de tempo iguais.
#
# Quando se quer observar o comportamento dos dados ao longo do tempo, usa-se o eixo x (horizontal) para representar a ordem cronológica e o eixo y para a variável dependente.

# %% [markdown]
# ## Plotar o gráfico de linhas
#
# Para exemplificar o gráfico de linhas, vou usar um *dataset* contendo o número de casos (mensal) de dengue para a cidade de Campinas-SP.
#
# Além do número de casos confirmados de dengue, o *dataset* mostra ainda dados relacionados à chuva, temperaturas média, mínima e máxima do município. O período contemplado pelo conjunto de dados é de 1998 a 2015.

# %%
#importar bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

#importar dados para dataframe
DATA_PATH = "https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/dengue-dataset.csv"
df = pd.read_csv(DATA_PATH)

#ver as 5 primeiras entradas
df.head()
# Out:
#          data  casos-confirmados  ...  temperatura-mininima  temperatura-maxima
# 0  1998-01-01                237  ...                  20.2                28.1
# 1  1998-02-01                331  ...                  20.0                28.0
# 2  1998-03-01                562  ...                  22.4                27.2
# 3  1998-04-01                187  ...                  18.1                26.0
# 4  1998-05-01                 32  ...                  15.7                22.9
#
# [5 rows x 6 columns]

# %%
#transformando a coluna DATA para objeto datetime
df.data = pd.to_datetime(df.data)
df.set_index('data', inplace = True)
df.head()
# Out:
#             casos-confirmados  chuva  ...  temperatura-mininima  temperatura-maxima
# data                                  ...
# 1998-01-01                237  179.2  ...                  20.2                28.1
# 1998-02-01                331  226.3  ...                  20.0                28.0
# 1998-03-01                562  149.1  ...                  22.4                27.2
# 1998-04-01                187   46.4  ...                  18.1                26.0
# 1998-05-01                 32   88.3  ...                  15.7                22.9
#
# [5 rows x 5 columns]

# %%
#plotar o número de casos confirmados (abordagem orientada a objeto)
fig, ax = plt.subplots()

ax.plot('casos-confirmados', data=df)
ax.set_title("Casos de Dengue em Campinas")
ax.set_xlabel("Ano")
ax.set_ylabel("Casos Confirmados")

#colocando as datas no eixo x em diagonal 
fig.autofmt_xdate()

plt.show()

# %%
#plotar o número de casos de temperatura média e temperatura máxima
fig, ax = plt.subplots()

ax.plot('temperatura-media', data=df)
ax.plot('temperatura-maxima', data=df)
ax.set_title("Casos de Dengue em Campinas")
ax.set_xlabel("Ano")
ax.set_ylabel("Casos Confirmados")

#colocando as datas no eixo x em diagonal 
fig.autofmt_xdate()

plt.show()

# %% [markdown]
# ## Selecionar intervalos

# %%
#plotar o histograma da temperatura média filtrando as datas de '2011-01-01': '2013-12-31'
fig, ax = plt.subplots()

#selecionar intervalo desejado
df_sel= df.loc['2011-01-01': '2013-12-31']

ax.set_title("Casos de Dengue em Campinas")
ax.set_xlabel("Ano")
ax.set_ylabel("Casos Confirmados")
ax.plot('casos-confirmados', data=df_sel)
fig.autofmt_xdate()

plt.show()

# %%
df.loc ['2011-01-01': '2013-12-31']
# Out:
#             casos-confirmados  chuva  ...  temperatura-mininima  temperatura-maxima
# data                                  ...
# 2011-01-01                 68  403.6  ...                  18.9                26.4
# 2011-02-01                288  166.8  ...                  21.3                26.4
# 2011-03-01                658  218.2  ...                  18.4                26.4
# 2011-04-01               1202   95.3  ...                  17.5                25.5
# 2011-05-01                714   41.9  ...                  15.1                21.5
# 2011-06-01                133   59.8  ...                   9.8                20.0
# 2011-07-01                 26    6.6  ...                  13.3                22.2
# 2011-08-01                 11   25.5  ...                  10.1                26.6
# 2011-09-01                 13   15.6  ...                  14.9                25.8
# 2011-10-01                 23  155.6  ...                  19.3                27.2
# 2011-11-01                 22  280.9  ...                  16.8                26.4
# 2011-12-01                 20  206.1  ...                  18.9                25.9
# 2012-01-01                 49  301.4  ...                  18.7                24.9
# 2012-02-01                 53  137.4  ...                  22.0                28.0
# 2012-03-01                152  148.4  ...                  18.6                26.7
# 2012-04-01                352  213.9  ...                  16.5                25.5
# 2012-05-01                205   73.1  ...                  13.0                21.1
# 2012-06-01                 88  165.5  ...                  16.0                21.5
# 2012-07-01                 18   40.6  ...                  11.7                22.6
# 2012-08-01                 12    NaN  ...                  17.5                21.6
# 2012-09-01                  8   24.3  ...                  12.2                27.0
# 2012-10-01                  6  100.7  ...                  18.5                29.0
# 2012-11-01                 11   93.9  ...                  20.5                27.8
# 2012-12-01                 25  133.3  ...                  21.4                28.2
# 2013-01-01                145  252.9  ...                  17.5                26.3
# 2013-02-01                496  136.5  ...                  20.5                27.5
# 2013-03-01               1853   15.3  ...                  19.3                27.4
# 2013-04-01               2703   93.3  ...                  18.3                25.9
# 2013-05-01               1277   62.8  ...                  14.8                23.8
# 2013-06-01                304   69.5  ...                  15.7                21.8
# 2013-07-01                 36   60.6  ...                   9.5                21.4
# 2013-08-01                 26    3.5  ...                   9.6                23.5
# 2013-09-01                 35   31.8  ...                  16.3                27.9
# 2013-10-01                 30   81.1  ...                  18.5                27.7
# 2013-11-01                 21   85.8  ...                  17.3                28.6
# 2013-12-01                 50   97.8  ...                  23.0                29.7
#
# [36 rows x 5 columns]

# %% [markdown]
# ## Plotar múltiplos gráficos separadamente

# %%
#plotar o histograma da temperatura média
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8, 4))

#plotar temperatura média
ax[0].plot('temperatura-media', data=df)
ax[0].set_title("Temperatura Média")

#plotar casos confirmados
ax[1].plot('casos-confirmados', data=df)
ax[1].set_title("Casos Confirmados")


#visualizacao boa (ajustar o layout)
plt.tight_layout()

# %% [markdown]
# ## Plotar múltiplos gráficos sobrepostos

# %%
#plotar os gráficos normalizados (normalizar pois são variáveis diferentes)
df_norm= (df - df.mean()) / df.std()
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,4))

#plotar temperatura média 
df_norm.loc ['2010-01-01':'2013-12-31',"temperatura-media"].plot(kind="line",
                                                                ax=ax)

#plotar casos confirmados
df_norm.loc['2010-01-01':'2013-12-31':,"casos-confirmados"].plot(kind="line",
                                                                 ax=ax)

#nomear o eixo X e colocar o título
ax.set_xlabel('Mês/Ano')
ax.set_title('Temperatura Média x Casos Confirmados')

plt.tight_layout()
